# %% [markdown]
# **Important Equations**

# %% [markdown]
# Probability Oracle:
# $$
# \begin{aligned}
# O_{\mathrm{prob}}:\quad
# &\sum_k a_k
# |\theta_k\rangle_{\Theta}
# |0\rangle_{\mathrm{prob}}
# |0\rangle_{\mathrm{work}}
# \\
# &\longmapsto
# \sum_k a_k
# |\theta_k\rangle_{\Theta}
# \left(
# \sqrt{1-p(\theta_k)}\,|0\rangle_{\mathrm{prob}}
# +
# \sqrt{p(\theta_k)}\,|1\rangle_{\mathrm{prob}}
# \right)
# |\mathrm{work}(\theta_k;H_{\mathrm{prob}})\rangle_{\mathrm{work}} .
# \end{aligned}
# $$
#
#
# $$
# \begin{aligned}
# H_{\mathrm{prob}}
# &=
# \sum_j c_j P_j,
# \\
# p(\theta_k)
# &=
# f\!\left(
# \left\langle \psi(\theta_k)\left|
# H_{\mathrm{prob}}
# \right|\psi(\theta_k)\right\rangle
# \right)
# \\
# &=
# f\!\left(
# \left\langle \psi(\theta_k)\left|
# \sum_j c_jP_j
# \right|\psi(\theta_k)\right\rangle
# \right).
# \end{aligned}
# $$

# %% [markdown]
# Phase Oracle:
# $$
#
# \sum_k a_k
# |\theta_k\rangle_{\Theta}
# |0\rangle_{\mathrm{prob}}
# |0\rangle_{\mathrm{work}}
# \longmapsto
# \sum_k a_k
# e^{-it
# \left\langle \psi(\theta_k)\left|
# \sum_j c_j P_j
# \right|\psi(\theta_k)\right\rangle}
# |\theta_k\rangle_{\Theta}
# \left(
# \sqrt{1-p(\theta_k)}\,|0\rangle_{\mathrm{prob}}
# +
# \sqrt{p(\theta_k)}\,|1\rangle_{\mathrm{prob}}
# \right)
# |\mathrm{work}(\theta_k;H_{\mathrm{prob}})\rangle_{\mathrm{work}}
#
# $$

# %% [markdown]
# ## Complete phase-oracle construction chain
#
# $$
# \begin{aligned}
# H=\sum_j c_jP_j
# &\xrightarrow{
# \alpha=\sum_j|c_j|,\;
# |G\rangle=\sum_j\sqrt{\frac{|c_j|}{\alpha}}|j\rangle,\;
# \mathrm{SELECT}=\sum_j |j\rangle\langle j|\otimes \operatorname{sgn}(c_j)P_j
# }
# \langle G|\mathrm{SELECT}|G\rangle=\frac{H}{\alpha}
# \\[1.2em]
# &\xrightarrow{
# |\psi_k\rangle
# }
# p_k
# =
# \frac12-\frac12
# \left\langle \psi_k\left|\frac{H}{\alpha}\right|\psi_k\right\rangle
# \\[1.2em]
# &\xrightarrow{
# G_U^{(k)}=R_0\left(U_p^{(k)}\right)^\dagger R_{\mathrm{good}}U_p^{(k)}
# }
# G_U^{(k)}|\phi_{k,\pm}\rangle
# =
# e^{\pm i\varphi_k}|\phi_{k,\pm}\rangle,
# \qquad
# E_{k,\mathrm{norm}}=-\cos\varphi_k
# \\[1.2em]
# &\xrightarrow{
# e^{i\alpha t\cos\varphi}
# \approx
# \sum_{m=-M}^{M}\beta_m e^{im\varphi}
# }
# B_{\mathrm{LCU}}^{(k)}
# =
# \frac{1}{\lambda_\beta}
# \sum_{m=-M}^{M}
# \beta_m
# \left(G_U^{(k)}\right)^m
# \approx
# \frac{1}{\lambda_\beta}e^{-iE_kt}
# \\[1.2em]
# &\xrightarrow{\mathrm{OAA}}
# B_{\mathrm{OAA}}^{(k)}
# \approx
# 3B_{\mathrm{LCU}}^{(k)}
# -
# 4B_{\mathrm{LCU}}^{(k)}
# \left(B_{\mathrm{LCU}}^{(k)}\right)^\dagger
# B_{\mathrm{LCU}}^{(k)}
# \approx
# e^{-iE_kt}.
# \end{aligned}
# $$
#
# Final candidate-register action:
#
# $$
# \sum_k a_k|k\rangle_{\mathrm{cand}}|0\rangle_{\mathrm{work}}
# \longmapsto
# \sum_k a_k e^{-iE_kt}
# |k\rangle_{\mathrm{cand}}|0\rangle_{\mathrm{work}}
# +
# |\mathrm{junk}^{\perp}\rangle .
# $$
